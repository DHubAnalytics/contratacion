# %%
import os
import glob
import pandas as pd
import numpy as np

# %%
df = pd.concat([pd.read_csv(file_) for file_ in glob.glob(os.path.join('../data/', '*'))], ignore_index=True)

# %% [markdown]
# ### The Data

# %%
df.head().T
# Out:
#                                                              0  \
# year                                                      2016
# ocid                      ocds-5wno2w-CE-20160000536478-586277
# date                                 2016-05-16T00:00:00-05:00
# region                                              CHIMBORAZO
# title                        Orden de compra CE-20160000536478
# description   Orden de compra para adquirir los siguientes ...
# method                                                  direct
# suppliers                         KRONOS LABORATORIOS C. LTDA.
# buyer         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...
# amount                                              504.000000
# budget                                                     504
#
#                                                              1  \
# year                                                      2016
# ocid                      ocds-5wno2w-CE-20160000536479-586277
# date                                 2016-05-16T00:00:00-05:00
# region                                              CHIMBORAZO
# title                        Orden de compra CE-20160000536479
# description   Orden de compra para adquirir los siguientes ...
# method                                                  direct
# suppliers                         KRONOS LABORATORIOS C. LTDA.
# buyer         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...
# amount                                              376.000000
# budget                                                     376
#
#                                                              2  \
# year                                                      2016
# ocid                      ocds-5wno2w-CE-20160000536480-586277
# date                                 2016-05-16T00:00:00-05:00
# region                                              CHIMBORAZO
# title                        Orden de compra CE-20160000536480
# description   Orden de compra para adquirir los siguientes ...
# method                                                  direct
# suppliers                               LABORATORIOS H.G. C.A.
# buyer         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...
# amount                                              516.000000
# budget                                                     516
#
#                                                              3  \
# year                                                      2016
# ocid                      ocds-5wno2w-CE-20160000536481-586277
# date                                 2016-05-16T00:00:00-05:00
# region                                              CHIMBORAZO
# title                        Orden de compra CE-20160000536481
# description   Orden de compra para adquirir los siguientes ...
# method                                                  direct
# suppliers     LABORATORIOS INDUSTRIALES FARMACEUTICOS ECUAT...
# buyer         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...
# amount                                              136.000000
# budget                                                     136
#
#                                                              4
# year                                                      2016
# ocid                      ocds-5wno2w-CE-20160000536482-586277
# date                                 2016-05-16T00:00:00-05:00
# region                                              CHIMBORAZO
# title                        Orden de compra CE-20160000536482
# description   Orden de compra para adquirir los siguientes ...
# method                                                  direct
# suppliers     LABORATORIOS INDUSTRIALES FARMACEUTICOS ECUAT...
# buyer         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...
# amount                                              155.200000
# budget                                                   155.2

# %% [markdown]
# ### Duplicates

# %%
# 346875 duplicates found and removed
def get_shape(df):
    print(df.shape)
    return df

(df
 .pipe(get_shape)
 .drop_duplicates()
 .pipe(get_shape)
)
# Out:
# (1561991, 11)
# (1215116, 11)
#          year                                      ocid  \
# 0        2016      ocds-5wno2w-CE-20160000536478-586277
# 1        2016      ocds-5wno2w-CE-20160000536479-586277
# 2        2016      ocds-5wno2w-CE-20160000536480-586277
# 3        2016      ocds-5wno2w-CE-20160000536481-586277
# 4        2016      ocds-5wno2w-CE-20160000536482-586277
# ...       ...                                       ...
# 1561977  2022   ocds-5wno2w-RE-CSPS-UNAE-006-202-607247
# 1561978  2022       ocds-5wno2w-RE-GADCG-018-2022-89167
# 1561982  2022       ocds-5wno2w-CE-20220002245568-43246
# 1561985  2022       ocds-5wno2w-COTS-HGPT-001-2022-2418
# 1561986  2022    ocds-5wno2w-COTO-GADMCH-002-2022-43412
#
#                                date       region  \
# 0         2016-05-16T00:00:00-05:00   CHIMBORAZO
# 1         2016-05-16T00:00:00-05:00   CHIMBORAZO
# 2         2016-05-16T00:00:00-05:00   CHIMBORAZO
# 3         2016-05-16T00:00:00-05:00   CHIMBORAZO
# 4         2016-05-16T00:00:00-05:00   CHIMBORAZO
# ...                             ...          ...
# 1561977   2022-08-04T08:57:28-05:00        CAÑAR
# 1561978   2022-07-30T08:24:05-05:00      BOLIVAR
# 1561982   2022-07-26T00:00:00-05:00    PICHINCHA
# 1561985   2022-07-08T07:43:41-05:00   TUNGURAHUA
# 1561986   2022-07-21T08:26:55-05:00       MANABI
#
#                                       title  \
# 0         Orden de compra CE-20160000536478
# 1         Orden de compra CE-20160000536479
# 2         Orden de compra CE-20160000536480
# 3         Orden de compra CE-20160000536481
# 4         Orden de compra CE-20160000536482
# ...                                     ...
# 1561977         RE-CSPS-UNAE-006-202-607247
# 1561978             RE-GADCG-018-2022-89167
# 1561982   Orden de compra CE-20220002245568
# 1561985             COTS-HGPT-001-2022-2418
# 1561986          COTO-GADMCH-002-2022-43412
#
#                                                description    method  \
# 0         Orden de compra para adquirir los siguientes ...    direct
# 1         Orden de compra para adquirir los siguientes ...    direct
# 2         Orden de compra para adquirir los siguientes ...    direct
# 3         Orden de compra para adquirir los siguientes ...    direct
# 4         Orden de compra para adquirir los siguientes ...    direct
# ...                                                    ...       ...
# 1561977   Contratación de servicios comunicacionales pa...   limited
# 1561978   SERVICIO DE DIFUSIÓN PARA EL MEJORAMIENTO DE ...    direct
# 1561982   Orden de compra para adquirir los siguientes ...    direct
# 1561985   PROVISIÓN DE COMBUSTIBLE PARA LOS VEHÍCULOS M...      open
# 1561986   RECONSTRUCCION DEL PARQUE DEL PADRE Y CONSTRU...      open
#
#                                                  suppliers  \
# 0                             KRONOS LABORATORIOS C. LTDA.
# 1                             KRONOS LABORATORIOS C. LTDA.
# 2                                   LABORATORIOS H.G. C.A.
# 3         LABORATORIOS INDUSTRIALES FARMACEUTICOS ECUAT...
# 4         LABORATORIOS INDUSTRIALES FARMACEUTICOS ECUAT...
# ...                                                    ...
# 1561977                                               None
# 1561978                                               None
# 1561982                                   PHARMABRAND S.A.
# 1561985                                               None
# 1561986                                               None
#
#                                                      buyer          amount  \
# 0         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...      504.000000
# 1         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...      376.000000
# 2         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...      516.000000
# 3         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...      136.000000
# 4         DIRECCION DISTRITAL 06D03-CUMANDA-PALLATANGA-...      155.200000
# ...                                                    ...             ...
# 1561977             UNIVERSIDAD NACIONAL DE EDUCACION UNAE    50050.000000
# 1561978   GOBIERNO AUTÓNOMO DESCENTRALIZADO DEL CANTÓN ...     3200.000000
# 1561982   HOSPITAL DE ESPECIALIDADES FUERZAS ARMADAS NO. 1        2.478000
# 1561985                  GOBIERNO PROVINCIAL DE TUNGURAHUA   278568.080000
# 1561986                                 MUNICIPIO DE CHONE   245451.127300
#
#              budget
# 0               504
# 1               376
# 2               516
# 3               136
# 4             155.2
# ...             ...
# 1561977    55672.11
# 1561978        3200
# 1561982       2.478
# 1561985   278568.08
# 1561986   248932.44
#
# [1215116 rows x 11 columns]

# %% [markdown]
# ### Missing Values

# %%
(df
 .drop_duplicates()
 [~(df
    .drop_duplicates()
    .region
    .str
    .contains('^\s\d\d?'))]
 .replace('None', np.nan)
 .isna()
 .groupby(df.year)
 .mean()
 .style
 .format(lambda n: '{:.4f}'.format(n*100))
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ffcb4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >year</th>
#       <th class="col_heading level0 col1" >ocid</th>
#       <th class="col_heading level0 col2" >date</th>
#       <th class="col_heading level0 col3" >region</th>
#       <th class="col_heading level0 col4" >title</th>
#       <th class="col_heading level0 col5" >description</th>
#       <th class="col_heading level0 col6" >method</th>
#       <th class="col_heading level0 col7" >suppliers</th>
#       <th class="col_heading level0 col8" >buyer</th>
#       <th class="col_heading level0 col9" >amount</th>
#       <th class="col_heading level0 col10" >budget</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffcb4_level0_row0" class="row_heading level0 row0" >2016</th>
#       <td id="T_ffcb4_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_ffcb4_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_ffcb4_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_ffcb4_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_ffcb4_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_ffcb4_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_ffcb4_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_ffcb4_row0_col7" class="data row0 col7" >0.0006</td>
#       <td id="T_ffcb4_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_ffcb4_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_ffcb4_row0_col10" class="data row0 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ffcb4_level0_row1" class="row_heading level0 row1" >2017</th>
#       <td id="T_ffcb4_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_ffcb4_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_ffcb4_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_ffcb4_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_ffcb4_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_ffcb4_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_ffcb4_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_ffcb4_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_ffcb4_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_ffcb4_row1_col9" class="data row1 col9" >0.0000</td>
#       <td id="T_ffcb4_row1_col10" class="data row1 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ffcb4_level0_row2" class="row_heading level0 row2" >2018</th>
#       <td id="T_ffcb4_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_ffcb4_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_ffcb4_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_ffcb4_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_ffcb4_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_ffcb4_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_ffcb4_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_ffcb4_row2_col7" class="data row2 col7" >0.0008</td>
#       <td id="T_ffcb4_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_ffcb4_row2_col9" class="data row2 col9" >0.0000</td>
#       <td id="T_ffcb4_row2_col10" class="data row2 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ffcb4_level0_row3" class="row_heading level0 row3" >2019</th>
#       <td id="T_ffcb4_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_ffcb4_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_ffcb4_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_ffcb4_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_ffcb4_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_ffcb4_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_ffcb4_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_ffcb4_row3_col7" class="data row3 col7" >0.0675</td>
#       <td id="T_ffcb4_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_ffcb4_row3_col9" class="data row3 col9" >0.0000</td>
#       <td id="T_ffcb4_row3_col10" class="data row3 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ffcb4_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_ffcb4_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_ffcb4_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_ffcb4_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_ffcb4_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_ffcb4_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_ffcb4_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_ffcb4_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_ffcb4_row4_col7" class="data row4 col7" >0.0617</td>
#       <td id="T_ffcb4_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_ffcb4_row4_col9" class="data row4 col9" >0.0000</td>
#       <td id="T_ffcb4_row4_col10" class="data row4 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ffcb4_level0_row5" class="row_heading level0 row5" >2021</th>
#       <td id="T_ffcb4_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_ffcb4_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_ffcb4_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_ffcb4_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_ffcb4_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_ffcb4_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_ffcb4_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_ffcb4_row5_col7" class="data row5 col7" >0.0344</td>
#       <td id="T_ffcb4_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_ffcb4_row5_col9" class="data row5 col9" >0.0000</td>
#       <td id="T_ffcb4_row5_col10" class="data row5 col10" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ffcb4_level0_row6" class="row_heading level0 row6" >2022</th>
#       <td id="T_ffcb4_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_ffcb4_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_ffcb4_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_ffcb4_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_ffcb4_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_ffcb4_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_ffcb4_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_ffcb4_row6_col7" class="data row6 col7" >0.0352</td>
#       <td id="T_ffcb4_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_ffcb4_row6_col9" class="data row6 col9" >0.0000</td>
#       <td id="T_ffcb4_row6_col10" class="data row6 col10" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df
 [~(df
    .region
    .str
    .contains('^\s\d\d?'))]
 .applymap(lambda n: n.strip().lower().replace('none', '') if isinstance(n, str) else n)
 # .apply(lambda s_:s_.replace('none', ''))
 # .isna()
 # .groupby(df.region)
 # .mean()
 # .style
 # .format(lambda n: '{:.4f}'.format(n*100))
)
# Out:
#          year                                     ocid  \
# 0        2016     ocds-5wno2w-ce-20160000536478-586277
# 1        2016     ocds-5wno2w-ce-20160000536479-586277
# 2        2016     ocds-5wno2w-ce-20160000536480-586277
# 3        2016     ocds-5wno2w-ce-20160000536481-586277
# 4        2016     ocds-5wno2w-ce-20160000536482-586277
# ...       ...                                      ...
# 1561986  2022   ocds-5wno2w-coto-gadmch-002-2022-43412
# 1561987  2022  ocds-5wno2w-lics-cz3-hba-001-202-121258
# 1561988  2022   ocds-5wno2w-re1-ra-gadcc-004-202-45403
# 1561989  2022    ocds-5wno2w-re-cep-gzar-01-2022-31595
# 1561990  2022    ocds-5wno2w-re-cscd-eeasa-063-22-3233
#
#                               date      region  \
# 0        2016-05-16t00:00:00-05:00  chimborazo
# 1        2016-05-16t00:00:00-05:00  chimborazo
# 2        2016-05-16t00:00:00-05:00  chimborazo
# 3        2016-05-16t00:00:00-05:00  chimborazo
# 4        2016-05-16t00:00:00-05:00  chimborazo
# ...                            ...         ...
# 1561986  2022-07-21t08:26:55-05:00      manabi
# 1561987  2022-06-24t07:29:04-05:00  chimborazo
# 1561988  2022-06-09t07:08:43-05:00        loja
# 1561989  2022-07-15t08:34:31-05:00      el oro
# 1561990  2022-08-03t08:28:03-05:00  tungurahua
#
#                                      title  \
# 0        orden de compra ce-20160000536478
# 1        orden de compra ce-20160000536479
# 2        orden de compra ce-20160000536480
# 3        orden de compra ce-20160000536481
# 4        orden de compra ce-20160000536482
# ...                                    ...
# 1561986         coto-gadmch-002-2022-43412
# 1561987        lics-cz3-hba-001-202-121258
# 1561988         re1-ra-gadcc-004-202-45403
# 1561989          re-cep-gzar-01-2022-31595
# 1561990          re-cscd-eeasa-063-22-3233
#
#                                                description  method  \
# 0        orden de compra para adquirir los siguientes p...  direct
# 1        orden de compra para adquirir los siguientes p...  direct
# 2        orden de compra para adquirir los siguientes p...  direct
# 3        orden de compra para adquirir los siguientes p...  direct
# 4        orden de compra para adquirir los siguientes p...  direct
# ...                                                    ...     ...
# 1561986  reconstruccion del parque del padre y construc...    open
# 1561987  contratación del servicio de pólizas de seguro...    open
# 1561988  adquisicion de repuestos menores para el arreg...  direct
# 1561989  trabajos de remediación superficial y de galer...  direct
# 1561990  servicios de comunicación y difusión del accio...  direct
#
#                                                  suppliers  \
# 0                             kronos laboratorios c. ltda.
# 1                             kronos laboratorios c. ltda.
# 2                                   laboratorios h.g. c.a.
# 3        laboratorios industriales farmaceuticos ecuato...
# 4        laboratorios industriales farmaceuticos ecuato...
# ...                                                    ...
# 1561986
# 1561987
# 1561988
# 1561989
# 1561990
#
#                                                      buyer          amount  \
# 0        direccion distrital 06d03-cumanda-pallatanga-s...      504.000000
# 1        direccion distrital 06d03-cumanda-pallatanga-s...      376.000000
# 2        direccion distrital 06d03-cumanda-pallatanga-s...      516.000000
# 3        direccion distrital 06d03-cumanda-pallatanga-s...      136.000000
# 4        direccion distrital 06d03-cumanda-pallatanga-s...      155.200000
# ...                                                    ...             ...
# 1561986                                 municipio de chone   245451.127300
# 1561987                             hospital basico alausi     4267.150000
# 1561988                                municipio de calvas        0.000000
# 1561989  gobierno autonomo descentralizado municipal de...  1600512.880000
# 1561990  empresa electrica ambato regional centro norte...    73374.610000
#
#              budget
# 0               504
# 1               376
# 2               516
# 3               136
# 4             155.2
# ...             ...
# 1561986   248932.44
# 1561987     9448.29
# 1561988    23377.99
# 1561989  1600512.88
# 1561990    73374.61
#
# [1561943 rows x 11 columns]

# %%
(df
 [~(df
    .region
    .str
    .contains('^\s\d\d?'))]
 .apply(lambda s_:s_.)
)
# Out:
# 0       NaN
# 1    lokita
# 2    poyito
# 3       NaN
# dtype: object

# %% [markdown]
# ### Memory

# %%
(df
 .memory_usage(deep=True)
 .apply(lambda s_: s_ / 1000000)
 .pipe(lambda df_: pd.concat([df_, df.dtypes], axis = 1))
 .rename(columns={0:'memory', 1:'dtype'})
)
# Out:
#                  memory   dtype
# Index         12.495928     NaN
# year          12.495928   int64
# ocid         146.111533  object
# date         129.644349  object
# region       104.275575  object
# title        139.833061  object
# description  256.879964  object
# method       103.584980  object
# suppliers    153.588971  object
# buyer        169.779263  object
# amount       105.983935  object
# budget        99.851350  object

# %% [markdown]
# ### Numeric Types

# %%
for size in ['float16', 'float32', 'float64']:
    print(f'{size:}{np.finfo(size)}')

# %% [markdown]
# ### Non-Numeric Types

# %% [markdown]
# ### Datetime Types

# %% [markdown]
# ### Tweak Contrataciones

# %% [markdown]
# ### Anomalies

# %% [markdown]
# #### Region column contains estranged values

# %%
(df
 .region
 .unique()
)
# Out:
# array([' CHIMBORAZO', ' PICHINCHA', ' None', ' GALAPAGOS', ' TUNGURAHUA',
#        ' LOJA', ' CAÑAR', ' GUAYAS', ' ORELLANA', ' AZUAY', ' CARCHI',
#        ' MANABI', ' SANTA ELENA', ' NAPO', ' IMBABURA', ' EL ORO',
#        ' MORONA SANTIAGO', ' BOLIVAR', ' LOS RIOS', ' SUCUMBIOS',
#        ' SANTO DOMINGO DE LOS TSACHILAS', ' COTOPAXI', ' PASTAZA',
#        ' ESMERALDAS', ' ZAMORA CHINCHIPE', ' 2016-10-03T00:00:00-05:00',
#        ' 2017-05-24T00:00:00-05:00', ' 2017-06-08T00:00:00-05:00',
#        ' 2017-11-15T00:00:00-05:00', ' 2017-02-20T00:00:00-05:00',
#        ' 2017-09-28T00:00:00-05:00', ' 2017-10-11T00:00:00-05:00',
#        ' 2017-07-18T00:00:00-05:00', ' 2017-10-10T00:00:00-05:00',
#        ' 2017-10-26T00:00:00-05:00', ' 2018-03-26T00:00:00-05:00',
#        ' 2018-11-15T00:00:00-05:00', ' 2018-05-03T00:00:00-05:00',
#        ' 2018-05-07T00:00:00-05:00', ' 2018-03-28T00:00:00-05:00',
#        ' 2019-02-07T00:00:00-05:00', ' 2019-10-01T00:00:00-05:00',
#        ' 2019-12-03T00:00:00-05:00', ' 2020-09-08T00:00:00-05:00',
#        ' 2020-12-01T00:00:00-05:00', ' 2020-03-23T00:00:00-05:00',
#        ' 2020-07-17T00:00:00-05:00', ' 2020-10-27T00:00:00-05:00',
#        ' 2021-03-04T00:00:00-05:00', ' 2021-09-22T00:00:00-05:00',
#        ' 2022-07-30T08:23:47-05:00', ' 2022-07-11T00:00:00-05:00',
#        ' 2022-07-26T08:12:04-05:00', ' 2022-09-03T09:21:08-05:00',
#        ' 2022-08-23T09:03:30-05:00'], dtype=object)
